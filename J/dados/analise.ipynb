# %%
# read processos_trafico.csv
import pandas as pd

df = pd.read_csv('processos_trafico.csv')

# %%
df.head()
# Out:
#              Número processo          Categoria    comarca              vara  \
# 0  1502301-34.2021.8.26.0542  Tráfico de Drogas    Barueri  2ª Vara Criminal
# 1  1500659-48.2021.8.26.0567  Tráfico de Drogas     Ibiúna           2ª Vara
# 2  1507083-56.2021.8.26.0228  Tráfico de Drogas  SÃO PAULO  6ª Vara Criminal
# 3  1500100-87.2022.8.26.0557  Tráfico de Drogas   Barretos  2ª Vara Criminal
# 4  1501120-38.2020.8.26.0540  Tráfico de Drogas       Mauá  1ª Vara Criminal
#
#                                   juiz  Pena Base  Pena Definitiva  \
# 0        Fabio Calheiros do Nascimento     2555.0           3064.0
# 1          Dra. Daniele Machado Toledo      500.0            416.0
# 2  Erika Soares de Azevedo Mascarenhas     1825.0            605.0
# 3            LUCIANO DE OLIVEIRA SILVA     1825.0           2430.0
# 4        SANDRO RAFAEL BARBOSA PACHECO      500.0            166.0
#
#   Circunstâncias Judiciais           Circunstâncias Preponderantes  \
# ...

# %%
# Count unique values in juiz
df['juiz'].nunique()
# Out:
# 269

# %%
# Numero de processos por juiz
df['juiz'].value_counts()
# Out:
# juiz
# BRUNO LUIZ CASSIOLATO                 4
# Fernando Augusto Andrade Conceição    4
# Udo Wolff Dick Appolo Do Amaral       3
# Tatiana Franklin Regueira             3
# Luciano Franchi Lemes                 3
#                                      ..
# Maria Letícia Pozzi Buassi            1
# Natália Berti                         1
# Natasha Gabriella Azevedo Motta       1
# VANESSA APARECIDA BUENO               1
# Rodrigo Jae Hwa An                    1
# Name: count, Length: 269, dtype: int64
